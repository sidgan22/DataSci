# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BH.csv')

# %%
df.shape
# Out:
# (506, 14)

# %%
for i in df.columns:
    print(i)
# Out:
# CRIM
# ZN
# INDUS
# CHAS
# NOX
# RM
# AGE
# DIS
# RAD
# TAX
# PTRATIO
# LSTAT
# MEDV
# CAT.MEDV

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT.MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# 3   2.94  33.4         1
# 4   5.33  36.2         1

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#      LSTAT  MEDV  CAT.MEDV
# 501   9.67  22.4         0
# 502   9.08  20.6         0
# 503   5.64  23.9         0
# 504   6.48  22.0         0
# 505   7.88  11.9         0

# %%
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  CAT.MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
df.sort_values(by='CHAS').head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 341  0.01301  35.0   1.52     0  0.442  7.241  49.3  7.0379    1  284
# 340  0.06151   0.0   5.19     0  0.515  5.968  58.5  4.8122    5  224
# 339  0.05497   0.0   5.19     0  0.515  5.985  45.4  4.8122    5  224
# 338  0.03306   0.0   5.19     0  0.515  6.059  37.3  4.8122    5  224
#
#      PTRATIO  LSTAT  MEDV  CAT.MEDV
# 0       15.3   4.98  24.0         0
# 341     15.5   5.49  32.7         1
# 340     20.2   9.29  18.7         0
# 339     20.2   9.74  19.0         0
# 338     20.2   8.51  20.6         0

# %%
df.sort_values(by='CAT.MEDV').head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 350  0.06211  40.0   1.25     0  0.429  6.490  44.4  8.7921    1  335
# 349  0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1  335
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 347  0.01870  85.0   4.15     0  0.429  6.516  27.7  8.5353    4  351
#
#      PTRATIO  LSTAT  MEDV  CAT.MEDV
# 0       15.3   4.98  24.0         0
# 350     19.7   5.98  22.9         0
# 349     19.7   5.89  26.6         0
# 348     17.0   5.99  24.5         0
# 347     17.9   6.36  23.1         0

# %%
grp = df.groupby('CHAS')['MEDV']
grp.mean()
# Out:
# CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64

# %%
grp.median()
# Out:
# CHAS
# 0    20.9
# 1    23.3
# Name: MEDV, dtype: float64

# %%
sctplot=plt.scatter(df['LSTAT'],df['MEDV'],color='b')
sctplot

# %%
plt.hist(df['MEDV'],bins=10)
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
bp1 = sns.boxplot(x=df['CHAS'],y=df['MEDV'])

# %%
bp2 = sns.boxplot(x=df['CAT.MEDV'],y=df['LSTAT'])

# %%
ax = sns.pairplot(df)

# %%
plt.scatter(df['CRIM'],df['MEDV'],color='r')

# %%
x=df['CRIM'].apply(np.log)
y=df['MEDV'].apply(np.log)
plt.scatter(x,y,color='g')
plt.show()
